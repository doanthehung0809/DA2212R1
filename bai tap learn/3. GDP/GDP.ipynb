# %%
import pandas as pd
df_gdp = pd.read_csv("GDPlist.csv", encoding="ISO-8859-1")
df_gdp.head()
# Out:
#         Country      Continent  GDP (millions of US$)
# 0   Afghanistan           Asia                  18181
# 1       Albania         Europe                  12847
# 2       Algeria         Africa                 190709
# 3        Angola         Africa                 100948
# 4     Argentina  South America                 447644

# %% [markdown]
# # Bộ dữ liệu chứa bao nhiêu dòng, bao nhiêu cột?
# # Thang đo tương ứng của các thuộc tính được lưu trữ?

# %%
df_gdp.info()
# Bộ dữ liệu có 124 hàng và 3 cột
# Thang đo: Country: object, Continent: Object, GDP: int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                125 non-null    object
#  1   Continent              125 non-null    object
#  2   GDP (millions of US$)  125 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 3.1+ KB

# %% [markdown]
# # GDP của các quốc gia có đồng đều không?

# %%
df_country_sum = df_gdp.groupby("Country")["GDP (millions of US$)"].sum().sort_values(ascending=False)
df_country_sum
# GDP các quốc gia không đồng đều nhau
# Out:
# Country
#  United States       15094025
#  China                7298147
#  Japan                5869471
#  Germany              3577031
#  France               2776324
#                        ...
#  Mozambique             12827
#  Papua New Guinea       12655
#  Namibia                12461
#  Mauritius              11313
#  Mali                   10600
# Name: GDP (millions of US$), Length: 125, dtype: int64

# %% [markdown]
# # Mỗi châu lục có bao nhiêu quốc gia nằm trong bảng dữ liệu

# %%
df_country_continent = df_gdp.groupby("Continent")["Country"].count()
df_country_continent
# Out:
# Continent
# Africa           29
# Asia             36
# Europe           37
# North America    11
# Oceania           3
# South America     9
# Name: Country, dtype: int64

# %% [markdown]
# # Tổng GPD của các châu lục?

# %%
df_continent_sum = df_gdp.groupby("Continent")["GDP (millions of US$)"].sum()
df_continent_sum
# Out:
# Continent
# Africa            1820811
# Asia             24425891
# Europe           19139380
# North America    18238447
# Oceania           1662727
# South America     4141217
# Name: GDP (millions of US$), dtype: int64

# %% [markdown]
# # Top 10 quốc gia có GDP cao nhất

# %%
df_country_sum.sort_values(ascending=False).head(10)
# Out:
# Country
#  United States     15094025
#  China              7298147
#  Japan              5869471
#  Germany            3577031
#  France             2776324
#  Brazil             2492908
#  United Kingdom     2417570
#  Italy              2198730
#  Russia             1850401
#  Canada             1736869
# Name: GDP (millions of US$), dtype: int64

# %% [markdown]
# # Việt hoa tên các cột trong bảng dữ liệu: Country 🡪 Nuoc; Continent 🡪 Chauluc; GDP (millions of US$) 🡪 GDP (trieu $)

# %%
df_gdp.rename(columns={'Country':'Nuoc','Continent':'Chauluc','GDP (millions of US$)':'GDP(trieu)'}, inplace=True)
df_gdp
# Out:
#              Nuoc        Chauluc  GDP(trieu)
# 0     Afghanistan           Asia       18181
# 1         Albania         Europe       12847
# 2         Algeria         Africa      190709
# 3          Angola         Africa      100948
# 4       Argentina  South America      447644
# ..            ...            ...         ...
# 120    Uzbekistan           Asia       45353
# 121     Venezuela  South America      315841
# 122       Vietnam           Asia      122722
# 123         Yemen         Africa       33675
# 124        Zambia         Africa       19206
#
# [125 rows x 3 columns]

# %% [markdown]
# # Chèn thêm một cột “Thanhpho” vào sau cột “Nuoc”, giá trị ban đầu là giá trị của cột “Nuoc”

# %%
df_gdp.insert(1,"ThanhPho",df_gdp["Nuoc"],True)
df_gdp
# Out:
#              Nuoc      ThanhPho        Chauluc  GDP(trieu)
# 0     Afghanistan   Afghanistan           Asia       18181
# 1         Albania       Albania         Europe       12847
# 2         Algeria       Algeria         Africa      190709
# 3          Angola        Angola         Africa      100948
# 4       Argentina     Argentina  South America      447644
# ..            ...           ...            ...         ...
# 120    Uzbekistan    Uzbekistan           Asia       45353
# 121     Venezuela     Venezuela  South America      315841
# 122       Vietnam       Vietnam           Asia      122722
# 123         Yemen         Yemen         Africa       33675
# 124        Zambia        Zambia         Africa       19206
#
# [125 rows x 4 columns]

# %% [markdown]
# # Trong cột Thanhpho, thay giá trị Vietnam thành Hanoi; Làm tương tự với các nước còn lại.

# %%
df_gdp["ThanhPho"].replace("Afghanistan", "HaNoi", inplace=True)
df_gdp
# Out:
#              Nuoc      ThanhPho        Chauluc  GDP(trieu)
# 0     Afghanistan   Afghanistan           Asia       18181
# 1         Albania       Albania         Europe       12847
# 2         Algeria       Algeria         Africa      190709
# 3          Angola        Angola         Africa      100948
# 4       Argentina     Argentina  South America      447644
# ..            ...           ...            ...         ...
# 120    Uzbekistan    Uzbekistan           Asia       45353
# 121     Venezuela     Venezuela  South America      315841
# 122       Vietnam       Vietnam           Asia      122722
# 123         Yemen         Yemen         Africa       33675
# 124        Zambia        Zambia         Africa       19206
#
# [125 rows x 4 columns]

# %% [markdown]
# # Xóa các bản ghi có Chauluc là ‘Asia’

# %%
df1 = df_gdp.loc[df_gdp["Chauluc"]!="Asia"]
df1
# Out:
#                Nuoc        ThanhPho        Chauluc  GDP(trieu)
# 1           Albania         Albania         Europe       12847
# 2           Algeria         Algeria         Africa      190709
# 3            Angola          Angola         Africa      100948
# 4         Argentina       Argentina  South America      447644
# 5         Australia       Australia        Oceania     1488221
# ..              ...             ...            ...         ...
# 118   United States   United States  North America    15094025
# 119         Uruguay         Uruguay  South America       46872
# 121       Venezuela       Venezuela  South America      315841
# 123           Yemen           Yemen         Africa       33675
# 124          Zambia          Zambia         Africa       19206
#
# [89 rows x 4 columns]

# %% [markdown]
# # Xóa các bản ghi có GDP < 300000

# %%
df2 = df_gdp.loc[df_gdp["GDP(trieu)"]<300000]
df2.sort_values("GDP(trieu)",ascending=False)
# Out:
#                  Nuoc           ThanhPho        Chauluc  GDP(trieu)
# 70           Malaysia           Malaysia           Asia      278680
# 40            Finland            Finland         Europe      266553
# 97          Singapore          Singapore           Asia      259849
# 22              Chile              Chile  South America      248411
# 49          Hong Kong          Hong Kong           Asia      243302
# ..                ...                ...            ...         ...
# 75         Mozambique         Mozambique         Africa       12827
# 85   Papua New Guinea   Papua New Guinea        Oceania       12655
# 76            Namibia            Namibia         Africa       12461
# 72          Mauritius          Mauritius         Africa       11313
# 71               Mali               Mali         Africa       10600
#
# [90 rows x 4 columns]
