# %%
import pandas as pd
df = pd.read_csv(r"E:\Gymcode\DA\DA2212R1\bai tap learn\4. food turkey\FoodPrice_in_Turkey.csv",encoding="UTF-8")
df
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %% [markdown]
# # Bộ dữ liệu chứa bao nhiêu dòng, bao nhiêu cột

# %%
df.shape
# bộ dữ liệu có 7381 hàng và 8 cột
# Out:
# (7381, 8)

# %% [markdown]
# # Thang đo tương ứng của các thuộc tính được lưu trữ

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %% [markdown]
# # Giá trung bình của từng loại thực phẩm là bao nhiêu

# %%
df1 = df.groupby(["ProductName"])["Price"].mean()
df1.sort_values(ascending=False)
# Out:
# ProductName
# Milk (powder, infant formula) - Retail                    108.287696
# Fuel (gas) - Retail                                        83.976703
# Meat (mutton) - Retail                                     45.557209
# Cocoa (powder) - Retail                                    43.802339
# Coffee (instant) - Retail                                  43.295493
# Coffee - Retail                                            42.468075
# Meat (veal) - Retail                                       41.270904
# Wage (non-qualified labour, non-agricultural) - Retail     40.548182
# Oil (olive) - Retail                                       27.274547
# Tea - Retail                                               26.224393
# Cheese - Retail                                            25.522875
# Fish (fresh) - Retail                                      22.698257
# Groundnuts (shelled) - Retail                              21.832122
# ...

# %% [markdown]
# # Ghi dữ liệu

# %%
df.to_excel("save food turkye.xlsx")
df.to_html('demo_FoodPrice.html')
df.to_hdf('demo_FoodPrice.h5', 'table')

# %% [markdown]
# # Đổi tên

# %%
df.rename(columns={"Place":"Địa Điểm", "Price":"Giá"}, inplace=True)
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#       Giá
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %% [markdown]
# # Thêm cột mới

# %%
df["new_column"]="NaN"
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price new_column
# 0  4.4920        NaN
# 1  4.5786        NaN
# 2  4.7865        NaN
# 3  5.1337        NaN
# 4  5.5099        NaN

# %% [markdown]
# # Thêm dòng mới

# %%
df = df.append({"Place":"NaN","Productld":"30","ProductName":"Rice -Retail","Umld":10,"UmName":"KG","Month":12, "Year":2022, "Price":5.9,"new_column":"NaN"}, ignore_index=True)
df.tail()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10260\3640525240.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Place":"NaN","Productld":"30","ProductName":"Rice -Retail","Umld":10,"UmName":"KG","Month":12, "Year":2022, "Price":5.9,"new_column":"NaN"}, ignore_index=True)
#       Place  ProductId              ProductName  UmId UmName  Month  Year  \
# 7377  Izmir      502.0  Cocoa (powder) - Retail   5.0     KG      9  2019
# 7378  Izmir      502.0  Cocoa (powder) - Retail   5.0     KG     10  2019
# 7379  Izmir      502.0  Cocoa (powder) - Retail   5.0     KG     11  2019
# 7380  Izmir      502.0  Cocoa (powder) - Retail   5.0     KG     12  2019
# 7381    NaN        NaN             Rice -Retail   NaN     KG     12  2022
#
#         Price new_column Productld  Umld
# 7377  49.1176        NaN       NaN   NaN
# 7378  50.8347        NaN       NaN   NaN
# ...

# %% [markdown]
# # Xoá cột trong data frame

# %%
# Sử dụng hàm del
del df["new_column"]
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average       52.0  Rice - Retail   5.0     KG      5  2013
# 1  National Average       52.0  Rice - Retail   5.0     KG      6  2013
# 2  National Average       52.0  Rice - Retail   5.0     KG     11  2013
# 3  National Average       52.0  Rice - Retail   5.0     KG     12  2013
# 4  National Average       52.0  Rice - Retail   5.0     KG      1  2014
#
#     Price Productld  Umld
# 0  4.4920       NaN   NaN
# 1  4.5786       NaN   NaN
# 2  4.7865       NaN   NaN
# 3  5.1337       NaN   NaN
# 4  5.5099       NaN   NaN

# %%
# Xoá cột sử dụng phương thức pop
df.pop("Productld")
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 7377    NaN
# 7378    NaN
# 7379    NaN
# 7380    NaN
# 7381     30
# Name: Productld, Length: 7382, dtype: object

# %%
# Xoá cột sử dụng phương thức drop
df.drop("Umld", axis=1, inplace=True)
df
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average       52.0            Rice - Retail   5.0     KG
# 1     National Average       52.0            Rice - Retail   5.0     KG
# 2     National Average       52.0            Rice - Retail   5.0     KG
# 3     National Average       52.0            Rice - Retail   5.0     KG
# 4     National Average       52.0            Rice - Retail   5.0     KG
# ...                ...        ...                      ...   ...    ...
# 7377             Izmir      502.0  Cocoa (powder) - Retail   5.0     KG
# 7378             Izmir      502.0  Cocoa (powder) - Retail   5.0     KG
# 7379             Izmir      502.0  Cocoa (powder) - Retail   5.0     KG
# 7380             Izmir      502.0  Cocoa (powder) - Retail   5.0     KG
# 7381               NaN        NaN             Rice -Retail   NaN     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %%
# xoá nhiều cột sử dụng drop
df.drop(["Month", "Year"], axis=1, inplace=True)
df
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average       52.0            Rice - Retail   5.0     KG
# 1     National Average       52.0            Rice - Retail   5.0     KG
# 2     National Average       52.0            Rice - Retail   5.0     KG
# 3     National Average       52.0            Rice - Retail   5.0     KG
# 4     National Average       52.0            Rice - Retail   5.0     KG
# ...                ...        ...                      ...   ...    ...
# 7377             Izmir      502.0  Cocoa (powder) - Retail   5.0     KG
# 7378             Izmir      502.0  Cocoa (powder) - Retail   5.0     KG
# 7379             Izmir      502.0  Cocoa (powder) - Retail   5.0     KG
# 7380             Izmir      502.0  Cocoa (powder) - Retail   5.0     KG
# 7381               NaN        NaN             Rice -Retail   NaN     KG
#
#         Price
# 0      4.4920
# 1      4.5786
# 2      4.7865
# 3      5.1337
# 4      5.5099
# ...

# %% [markdown]
# # Xoá dòng trong data frame

# %%
df.drop(1, axis=0, inplace=True)
df
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average       52.0            Rice - Retail   5.0     KG
# 2     National Average       52.0            Rice - Retail   5.0     KG
# 3     National Average       52.0            Rice - Retail   5.0     KG
# 4     National Average       52.0            Rice - Retail   5.0     KG
# 5     National Average       52.0            Rice - Retail   5.0     KG
# ...                ...        ...                      ...   ...    ...
# 7377             Izmir      502.0  Cocoa (powder) - Retail   5.0     KG
# 7378             Izmir      502.0  Cocoa (powder) - Retail   5.0     KG
# 7379             Izmir      502.0  Cocoa (powder) - Retail   5.0     KG
# 7380             Izmir      502.0  Cocoa (powder) - Retail   5.0     KG
# 7381               NaN        NaN             Rice -Retail   NaN     KG
#
#         Price
# 0      4.4920
# 2      4.7865
# 3      5.1337
# 4      5.5099
# 5      5.8146
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7381 entries, 0 to 7381
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7380 non-null   float64
#  2   ProductName  7381 non-null   object
#  3   UmId         7380 non-null   float64
#  4   UmName       7381 non-null   object
#  5   Price        7381 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 403.6+ KB
